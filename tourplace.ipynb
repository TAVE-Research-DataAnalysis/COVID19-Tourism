# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

plt.rcParams['font.family'] = 'NanumGothic'
# %matplotlib inline

curr_dir = os.getcwd()

# %%
df = pd.read_csv(curr_dir + "/data/제주특별자치도_제주도장소(POI)데이터_20151231.csv", encoding='cp949')

# %%
df
# Out:
#        장소 POI에 대한 ID 구분 번호 체계    위치좌표 X축값   위치좌표 Y축값      구분              장소명  \
# 0                            3  126.568803  33.236546   교통시설             동방파제
# 1                            4  126.562554  33.235071   지명관련               새섬
# 2                            5  126.599675  33.230314   지명관련               섶섬
# 3                            6  126.565891  33.226031   지명관련               문섬
# 4                            7  126.516395  33.218414   지명관련               범섬
# ...                        ...         ...        ...    ...              ...
# 74434                    76264  126.542149  33.492701   교육기관       제주CMS에듀케이션
# 74435                    76265  126.507533  33.248077  자동차관련  이마트서귀포점전기자동차충전기
# 74436                    76266  126.520938  33.517848  자동차관련   이마트제주점전기자동차충전기
# 74437                    76267  126.282677  33.288644  쇼핑/편의      제주영어마을지에스25
# 74438                    76268  126.545387  33.477969  자동차관련          현대정비아라점
#
# ...

# %%
df['구분'].unique()
# Out:
# array(['교통시설', '지명관련', '공공기관', '교육기관', '주택관련', '기업', '관광/숙박', '문화/종교/예술',
#        '도로시설', '언론기관', '의료/복지', '자동차관련', '농공시설', '공원/산/동.식물원', '치안기관',
#        '음식점', '금융기관', '레져/스포츠', '쇼핑/편의', '공사중명칭'], dtype=object)

# %%
df.groupby(['구분']).head(3)
# Out:
#        장소 POI에 대한 ID 구분 번호 체계    위치좌표 X축값   위치좌표 Y축값           구분  \
# 0                            3  126.568803  33.236546        교통시설
# 1                            4  126.562554  33.235071        지명관련
# 2                            5  126.599675  33.230314        지명관련
# 3                            6  126.565891  33.226031        지명관련
# 5                            8  126.222533  33.241524        공공기관
# 8                           11  126.270300  33.425837        교육기관
# 9                           12  126.312871  33.420172        교육기관
# 10                          13  126.293435  33.442419        교육기관
# 13                          16  126.482967  33.491867        주택관련
# 14                          17  126.473406  33.483001        주택관련
# 16                          19  126.480730  33.488767        주택관련
# 20                          23  126.452608  33.469477          기업
# 21                          24  126.373127  33.469534          기업
# ...

# %%
df[df['구분'].isin(['관광/숙박', '문화/종교/예술', '공원/산/동.식물원', '레져/스포츠'])]
# Out:
#        장소 POI에 대한 ID 구분 번호 체계    위치좌표 X축값   위치좌표 Y축값         구분        장소명  \
# 29                          32  126.495979  33.486592     관광/숙박     코리아나호텔
# 30                          33  126.448871  33.465586  문화/종교/예술        해성사
# 39                          42  126.385364  33.470809     관광/숙박      수산유원지
# 73                          77  126.771241  33.529109     관광/숙박        만장굴
# 80                          84  126.910056  33.441262  문화/종교/예술        남안사
# ...                        ...         ...        ...       ...        ...
# 74407                    76234  126.674899  33.544272    레져/스포츠  함덕해수욕장야영장
# 74409                    76236  126.735810  33.382333    레져/스포츠   조랑말공원캠프장
# 74423                    76250  126.366465  33.475708     관광/숙박    BE2IN팬션
# 74429                    76259  126.366841  33.449328     관광/숙박     하늬바람펜션
# 74430                    76260  126.512445  33.233646     관광/숙박      플라야팬션
#
#                              소재지     데이터기준일자
# ...
